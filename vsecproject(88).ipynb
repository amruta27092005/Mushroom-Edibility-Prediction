# %% [markdown]
# Name-Patil Amruta Roll no-2317088 Batch-'A' sub-mushrooms  import   pandas   as   pd    import   seaborn   as   sns    import   numpy   as   np    import   matplotlib.pyplot   as   plt    #Attribute Information: (classes: edible=e, poisonous=p)    #cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s    #cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s    #cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,ye #bruises: bruises=t,no=f    #odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s    #gill-attachment: attached=a,descending=d,free=f,notched=n    #gill-spacing: close=c,crowded=w,distant=d    #gill-size: broad=b,narrow=n    #gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purpl #stalk-shape: enlarging=e,tapering=t    #stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?    #stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s    #stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s    #stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white #stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white #veil-type: partial=p,universal=u    #veil-color: brown=n,orange=o,white=w,yellow=y    #ring-number: none=n,one=o,two=t    #ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zo #spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,whit #population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y    #habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d    df = pd . read_csv ( "mushrooms.csv" )    df   In [348 ... In [350 ... In [352 ... In [354 ... In [356 ... In [358 ... In [360 ...

# %% [markdown]
# --- End of Page 1 ---

# %% [markdown]
# df . head ()    df . tail ()    from   sklearn.preprocessing   import   LabelEncoder   le = LabelEncoder ()  for   col   in   df . select_dtypes ( include = 'object' ) . columns :    class   cap- shape cap- surface cap- color   bruises   odor   gill- attachment gill- spacing gill- size gill- color   ... 0   p   x   s   n   t   p   f   c   n   k   ...  1   e   x   s   y   t   a   f   c   b   k   ...  2   e   b   s   w   t   l   f   c   b   n   ...  3   p   x   y   w   t   p   f   c   n   n   ...  4   e   x   s   g   f   n   f   w   b   k   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  8119   e   k   s   n   f   n   a   c   b   y   ...  8120   e   x   s   n   f   n   a   c   b   y   ...  8121   e   f   s   n   f   n   a   c   b   n   ...  8122   p   k   y   n   f   y   f   c   n   b   ...  8123   e   x   s   n   f   n   a   c   b   y   ...  8124 rows × 23 columns  class   cap- shape cap- surface cap- color   bruises   odor   gill- attachment gill- spacing gill- size gill- color   ...   su b 0   p   x   s   n   t   p   f   c   n   k   ...  1   e   x   s   y   t   a   f   c   b   k   ...  2   e   b   s   w   t   l   f   c   b   n   ...  3   p   x   y   w   t   p   f   c   n   n   ...  4   e   x   s   g   f   n   f   w   b   k   ...  5 rows × 23 columns  class   cap- shape cap- surface cap- color   bruises   odor   gill- attachment gill- spacing gill- size  gill- color   ... 8119   e   k   s   n   f   n   a   c   b   y   ...  8120   e   x   s   n   f   n   a   c   b   y   ...  8121   e   f   s   n   f   n   a   c   b   n   ...  8122   p   k   y   n   f   y   f   c   n   b   ...  8123   e   x   s   n   f   n   a   c   b   y   ...  5 rows × 23 columns Out[360 ... In [362 ... Out[362 ... In [364 ... Out[364 ... In [366 ... In [368 ...

# %% [markdown]
# --- End of Page 2 ---

# %% [markdown]
# df [ col ]   =   le . fit_transform ( df [ col ])    df    df . isnull ()         df . isnull () . sum ()    class   cap- shape cap- surface cap- color   bruises   odor   gill- attachment gill- spacing gill- size gill- color   ... 0   1   5   2   4   1   6   1   0   1   4   ...  1   0   5   2   9   1   0   1   0   0   4   ...  2   0   0   2   8   1   3   1   0   0   5   ...  3   1   5   3   8   1   6   1   0   1   5   ...  4   0   5   2   3   0   5   1   1   0   4   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  8119   0   3   2   4   0   5   0   0   0   11   ...  8120   0   5   2   4   0   5   0   0   0   11   ...  8121   0   2   2   4   0   5   0   0   0   5   ...  8122   1   3   3   4   0   8   1   0   1   0   ...  8123   0   5   2   4   0   5   0   0   0   11   ...  8124 rows × 23 columns  class   cap- shape cap- surface cap- color   bruises   odor   gill- attachment gill- spacing gill- size gill- color   ... 0   False   False   False   False   False   False   False   False   False   False   ..  1   False   False   False   False   False   False   False   False   False   False   ..  2   False   False   False   False   False   False   False   False   False   False   ..  3   False   False   False   False   False   False   False   False   False   False   ..  4   False   False   False   False   False   False   False   False   False   False   ..  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ..  8119   False   False   False   False   False   False   False   False   False   False   ..  8120   False   False   False   False   False   False   False   False   False   False   ..  8121   False   False   False   False   False   False   False   False   False   False   ..  8122   False   False   False   False   False   False   False   False   False   False   ..  8123   False   False   False   False   False   False   False   False   False   False   ..  8124 rows × 23 columns In [370 ... Out[370 ... In [372 ... Out[372 ... In [ ]: In [375 ...

# %% [markdown]
# --- End of Page 3 ---

# %% [markdown]
# class                       0   cap-shape                   0   cap-surface                 0   cap-color                   0   bruises                     0   odor                        0   gill-attachment             0   gill-spacing                0   gill-size                   0   gill-color                  0   stalk-shape                 0   stalk-root                  0   stalk-surface-above-ring    0   stalk-surface-below-ring    0   stalk-color-above-ring      0   stalk-color-below-ring      0   veil-type                   0   veil-color                  0   ring-number                 0   ring-type                   0   spore-print-color           0   population                  0   habitat                     0   dtype: int64  df . isnull () . count ()    class                       8124   cap-shape                   8124   cap-surface                 8124   cap-color                   8124   bruises                     8124   odor                        8124   gill-attachment             8124   gill-spacing                8124   gill-size                   8124   gill-color                  8124   stalk-shape                 8124   stalk-root                  8124   stalk-surface-above-ring    8124   stalk-surface-below-ring    8124   stalk-color-above-ring      8124   stalk-color-below-ring      8124   veil-type                   8124   veil-color                  8124   ring-number                 8124   ring-type                   8124   spore-print-color           8124   population                  8124   habitat                     8124   dtype: int64  df . dropna ( axis = 0 , inplace = True )    df   Out[375 ... In [377 ... Out[377 ... In [379 ... In [381 ...

# %% [markdown]
# --- End of Page 4 ---

# %% [markdown]
# df . isnull () . sum ()    class                       0   cap-shape                   0   cap-surface                 0   cap-color                   0   bruises                     0   odor                        0   gill-attachment             0   gill-spacing                0   gill-size                   0   gill-color                  0   stalk-shape                 0   stalk-root                  0   stalk-surface-above-ring    0   stalk-surface-below-ring    0   stalk-color-above-ring      0   stalk-color-below-ring      0   veil-type                   0   veil-color                  0   ring-number                 0   ring-type                   0   spore-print-color           0   population                  0   habitat                     0   dtype: int64  df . dropna ()    class   cap- shape cap- surface cap- color   bruises   odor   gill- attachment gill- spacing gill- size gill- color   ... 0   1   5   2   4   1   6   1   0   1   4   ...  1   0   5   2   9   1   0   1   0   0   4   ...  2   0   0   2   8   1   3   1   0   0   5   ...  3   1   5   3   8   1   6   1   0   1   5   ...  4   0   5   2   3   0   5   1   1   0   4   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  8119   0   3   2   4   0   5   0   0   0   11   ...  8120   0   5   2   4   0   5   0   0   0   11   ...  8121   0   2   2   4   0   5   0   0   0   5   ...  8122   1   3   3   4   0   8   1   0   1   0   ...  8123   0   5   2   4   0   5   0   0   0   11   ...  8124 rows × 23 columns Out[381 ... In [383 ... Out[383 ... In [385 ...

# %% [markdown]
# --- End of Page 5 ---

# %% [markdown]
# df . shape    (8124, 23)  df.size  df . ndim    2  df . describe ()    df . info ()    class   cap- shape cap- surface cap- color   bruises   odor   gill- attachment gill- spacing gill- size gill- color   ... 0   1   5   2   4   1   6   1   0   1   4   ...  1   0   5   2   9   1   0   1   0   0   4   ...  2   0   0   2   8   1   3   1   0   0   5   ...  3   1   5   3   8   1   6   1   0   1   5   ...  4   0   5   2   3   0   5   1   1   0   4   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  8119   0   3   2   4   0   5   0   0   0   11   ...  8120   0   5   2   4   0   5   0   0   0   11   ...  8121   0   2   2   4   0   5   0   0   0   5   ...  8122   1   3   3   4   0   8   1   0   1   0   ...  8123   0   5   2   4   0   5   0   0   0   11   ...  8124 rows × 23 columns  class   cap-shape   cap-surface   cap-color   bruises   odor   a count   8124.000000   8124.000000   8124.000000   8124.000000   8124.000000   8124.000000   8  mean   0.482029   3.348104   1.827671   4.504677   0.415559   4.144756  std   0.499708   1.604329   1.229873   2.545821   0.492848   2.103729  min   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000  25%   0.000000   2.000000   0.000000   3.000000   0.000000   2.000000  50%   0.000000   3.000000   2.000000   4.000000   0.000000   5.000000  75%   1.000000   5.000000   3.000000   8.000000   1.000000   5.000000  max   1.000000   5.000000   3.000000   9.000000   1.000000   8.000000  8 rows × 23 columns Out[385 ... In [387 ... Out[387 ... In [389 ... Out[389 ... In [399 ... Out[399 ... In [401 ...

# %% [markdown]
# --- End of Page 6 ---

# %% [markdown]
# <class 'pandas.core.frame.DataFrame'>   RangeIndex: 8124 entries, 0 to 8123   Data columns (total 23 columns):    #   Column                    Non-Null Count  Dtype   ---  ------                    --------------  -----    0   class                     8124 non-null   int64    1   cap-shape                 8124 non-null   int64    2   cap-surface               8124 non-null   int64    3   cap-color                 8124 non-null   int64    4   bruises                   8124 non-null   int64    5   odor                      8124 non-null   int64    6   gill-attachment           8124 non-null   int64    7   gill-spacing              8124 non-null   int64    8   gill-size                 8124 non-null   int64    9   gill-color                8124 non-null   int64    10  stalk-shape               8124 non-null   int64    11  stalk-root                8124 non-null   int64    12  stalk-surface-above-ring  8124 non-null   int64    13  stalk-surface-below-ring  8124 non-null   int64    14  stalk-color-above-ring    8124 non-null   int64    15  stalk-color-below-ring    8124 non-null   int64    16  veil-type                 8124 non-null   int64    17  veil-color                8124 non-null   int64    18  ring-number               8124 non-null   int64    19  ring-type                 8124 non-null   int64    20  spore-print-color         8124 non-null   int64    21  population                8124 non-null   int64    22  habitat                   8124 non-null   int64   dtypes: int64(23)   memory usage: 1.4 MB    B = df . select_dtypes ( 'category' )   B    0 1 2 3 4 ... 8119 8120 8121 8122 8123  8124 rows × 0 columns  df   [ 'class' ] . unique ()    array([1, 0])  df   [ 'cap-shape' ] . nunique ()    6  df [ 'cap-shape' ] . count ()   In [403 ... Out[403 ... In [405 ... Out[405 ... In [407 ... Out[407 ... In [409 ...

# %% [markdown]
# --- End of Page 7 ---

# %% [markdown]
# 8124  df [ 'cap-shape' ] . value_counts ()    cap-shape   5    3656   2    3152   3     828   0     452   4      32   1       4   Name: count, dtype: int64  def   detect_outliers_iqr ( data ):        outliers   =   {}        for   col   in   data . select_dtypes ( include = [ 'number' ]) . columns :            Q1   =   np . percentile ( data [ col ],   25 ,   interpolation = 'midpoint' )            Q3   =   np . percentile ( data [ col ],   75 ,   interpolation = 'midpoint' )            IQR   =   Q3   -   Q1            lower_bound   =   Q1   -   1.5   *   IQR            upper_bound   =   Q3   +   1.5   *   IQR            outliers [ col ]   =   data [( data [ col ]   <   lower_bound )   |   ( data [ col ]   >   upper_bound )][ c      return   outliers    outliers   =   detect_outliers_iqr ( df )   print ( outliers )   Out[409 ... In [411 ... Out[411 ... In [413 ... In [425 ...

# %% [markdown]
# --- End of Page 8 ---

# %% [markdown]
# {'class': Series([], Name: class, dtype: int64), 'cap-shape': Series([], Name: cap-sha pe, dtype: int64), 'cap-surface': Series([], Name: cap-surface, dtype: int64), 'cap-co lor': Series([], Name: cap-color, dtype: int64), 'bruises': Series([], Name: bruises,   dtype: int64), 'odor': Series([], Name: odor, dtype: int64), 'gill-attachment': 6038     0   6040    0   6375    0   6424    0   6434    0         ..   8115    0   8119    0   8120    0   8121    0   8123    0   Name: gill-attachment, Length: 210, dtype: int64, 'gill-spacing': 4       1   14      1   16      1   29      1   35      1         ..   8094    1   8096    1   8099    1   8109    1   8111    1   Name: gill-spacing, Length: 1312, dtype: int64, 'gill-size': Series([], Name: gill-siz e, dtype: int64), 'gill-color': Series([], Name: gill-color, dtype: int64), 'stalk-sha pe': Series([], Name: stalk-shape, dtype: int64), 'stalk-root': 0       3   3       3   4       3   8       3   13      3         ..   2817    3   2844    3   2881    3   2890    3   2966    3   Name: stalk-root, Length: 1312, dtype: int64, 'stalk-surface-above-ring': Series([], N ame: stalk-surface-above-ring, dtype: int64), 'stalk-surface-below-ring': Series([], N ame: stalk-surface-below-ring, dtype: int64), 'stalk-color-above-ring': 305     3   384     3   449     3   873     3   890     3         ..   7984    4   7986    4   8001    4   8095    1   8114    1   Name: stalk-color-above-ring, Length: 1588, dtype: int64, 'stalk-color-below-ring': 63 2     3   944     3   963     3   1030    3   1043    3         ..   7984    4   7986    4   8001    4   8095    1   8114    1   Name: stalk-color-below-ring, Length: 1652, dtype: int64, 'veil-type': Series([], Nam e: veil-type, dtype: int64), 'veil-color': 6038    0

# %% [markdown]
# --- End of Page 9 ---

# %% [markdown]
# 6040    0   6375    1   6424    0   6434    0         ..   8115    1   8119    1   8120    0   8121    1   8123    1   Name: veil-color, Length: 200, dtype: int64, 'ring-number': 3984    2   4106    2   4283    2   4291    2   4357    2         ..   8096    2   8099    2   8109    2   8111    2   8114    0   Name: ring-number, Length: 636, dtype: int64, 'ring-type': Series([], Name: ring-type,   dtype: int64), 'spore-print-color': Series([], Name: spore-print-color, dtype: int64),   'population': 4       0   14      0   16      0   56      0   65      0         ..   8107    1   8114    1   8119    1   8121    1   8123    1   Name: population, Length: 724, dtype: int64, 'habitat': 3984    6   4283    6   4291    6   4357    6   4380    6         ..   5939    6   5953    6   5961    6   5976    6   5996    6   Name: habitat, Length: 192, dtype: int64}         LOGISTIC REGRESSION  import   sklearn   as   sk    x = df . drop ( columns = 'class' )   y = df [ 'class' ]    from   sklearn.model_selection   import   train_test_split    x_train , x_test , y_train , y_test = train_test_split ( x , y , train_size = 0.8 , test_size = 0.2 , rando  len ( x_train )   In [ ]: In [429 ... In [431 ... In [433 ... In [435 ... In [437 ...

# %% [markdown]
# --- End of Page 10 ---

# %% [markdown]
# 6499  len ( y_train )    6499  len ( x_test )    1625  len ( y_test )    1625  x_train . shape    (6499, 22)  y_train . shape    (6499,)  x_test . shape    (1625, 22)  y_test . shape    (1625,)  from   sklearn.linear_model   import   LogisticRegression   model = LogisticRegression ()    model    model . fit ( x_train , y_train )    /home/admin1/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:4 60: ConvergenceWarning: lbfgs failed to converge (status=1):   STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.   Increase the number of iterations (max_iter) or scale the data as shown in:      https://scikit-learn.org/stable/modules/preprocessing.html   Please also refer to the documentation for alternative solver options:      https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression    n_iter_i = _check_optimize_result(    y_pred = model . predict ( x_test )    y_pred    array([0, 1, 0, ..., 1, 0, 0]) Out[437 ... In [439 ... Out[439 ... In [441 ... Out[441 ... In [443 ... Out[443 ... In [445 ... Out[445 ... In [447 ... Out[447 ... In [449 ... Out[449 ... In [451 ... Out[451 ... In [453 ... In [455 ... Out[455 ... In [457 ... Out[457 ... In [459 ... In [461 ... Out[461 ...  ▾   LogisticRegression  LogisticRegression()  ▾   LogisticRegression  LogisticRegression()

# %% [markdown]
# --- End of Page 11 ---

# %% [markdown]
# model . score ( x_test , y_test )    0.9526153846153846  from   sklearn.metrics   import   accuracy_score    logistic_accu = accuracy_score ( y_test , y_pred )    logistic_accu    0.9526153846153846  from   sklearn.metrics   import   confusion_matrix , accuracy_score    from   sklearn.preprocessing   import   StandardScaler    cm = confusion_matrix ( y_test , y_pred )   cm    array([[826,  35],          [ 42, 722]])  sns . heatmap ( cm , annot = True , fmt = 'g' )    <Axes: >  cm . ravel ()    array([826,  35,  42, 722])  tn   ,   fp   , fn   ,   tp =   confusion_matrix ( y_test , y_pred ) . ravel ()   print ( f 'True Positive (TP):  { tp } ' ) print ( f 'True Negative (TN):  { tn } ' ) print ( f 'False Positive (FP):  { fp } ' )   print ( f 'False Negative (FN):  { fn } ' )    True Positive (TP): 722   True Negative (TN): 826   False Positive (FP): 35   False Negative (FN): 42   In [463 ... Out[463 ... In [465 ... In [467 ... In [469 ... Out[469 ... In [471 ... In [473 ... Out[473 ... In [475 ... Out[475 ... In [477 ... Out[477 ... In [479 ...

# %% [markdown]
# --- End of Page 12 ---

# %% [markdown]
# accuracy = ( tp + tn ) / ( tp + tn + fp + fn )    accuracy    0.9526153846153846  from   sklearn.metrics   import   classification_report   print ( classification_report ( y_test , y_pred ))                  precision    recall  f1-score   support                0       0.95      0.96      0.96       861              1       0.95      0.95      0.95       764         accuracy                           0.95      1625      macro avg       0.95      0.95      0.95      1625   weighted avg       0.95      0.95      0.95      1625      from   sklearn.metrics   import   precision_score    print ( precision_score ( y_test , y_pred ))    0.9537648612945839    recall = tp / ( tp + fn )    print ( recall )    0.9450261780104712    precision = tp / ( tp + fp )    precision    0.9537648612945839  f1_score = 2 * (( precision * recall ) / ( precision + recall ))    print ( f1_score )    0.9493754109138725    NAIVE BAYES  import   sklearn   as   sk    x = df . drop ( columns = 'class' )   y = df [ 'class' ]    from   sklearn.model_selection   import   train_test_split    x_train , x_test , y_train , y_test = train_test_split ( x , y , train_size = 0.8 , test_size = 0.2 , rando  x_train   In [481 ... In [483 ... Out[483 ... In [485 ... In [487 ... In [489 ... In [491 ... In [493 ... In [495 ... In [497 ... Out[497 ... In [499 ... In [501 ... In [504 ... In [506 ... In [508 ... In [510 ... In [512 ...

# %% [markdown]
# --- End of Page 13 ---

# %% [markdown]
# y_train    2321    0   6705    1   5583    1   5495    1   6819    1          ..   3441    1   1344    0   4623    1   7293    0   1289    0   Name: class, Length: 6499, dtype: int64  x_test    cap- shape cap- surface cap- color   bruises   odor   gill- attachment gill- spacing gill- size gill- color stalk- shape   .. 2321   5   3   2   1   5   1   0   0   10   1   ..  6705   5   2   4   0   8   1   0   1   0   1   ..  5583   5   3   4   0   8   1   0   1   0   1   ..  5495   2   3   9   0   2   1   0   0   2   0   ..  6819   2   2   4   0   8   1   0   1   0   1   ..  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ..  3441   5   0   5   0   1   1   0   1   5   0   ..  1344   2   2   8   0   5   1   1   0   5   1   ..  4623   2   3   3   0   2   1   0   0   3   0   ..  7293   3   2   3   0   5   1   1   0   10   0   ..  1289   2   2   8   0   5   1   1   0   5   1   ..  6499 rows × 22 columns Out[512 ... In [514 ... Out[514 ... In [516 ...

# %% [markdown]
# --- End of Page 14 ---

# %% [markdown]
# y_test    582     0   2288    1   1789    0   3374    0   814     1          ..   2572    0   5045    1   4995    1   3359    1   2729    0   Name: class, Length: 1625, dtype: int64  from   sklearn.naive_bayes   import   GaussianNB    model = GaussianNB ()    model    model . fit ( x_train , y_train )    y_pred = model . predict ( x_test )    y_pred    array([0, 1, 0, ..., 1, 0, 0])  cap- shape cap- surface cap- color   bruises   odor   gill- attachment gill- spacing gill- size gill- color stalk- shape   .. 582   5   3   8   1   3   1   0   0   4   0   ..  2288   2   2   4   1   6   1   0   1   7   0   ..  1789   5   2   8   0   5   1   1   0   5   1   ..  3374   2   3   2   1   5   1   0   0   9   1   ..  814   5   2   4   1   6   1   0   1   4   0   ..  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ..  2572   5   3   4   1   5   1   0   0   10   1   ..  5045   2   0   3   0   2   1   0   0   3   0   ..  4995   2   3   9   0   2   1   0   0   3   0   ..  3359   5   0   3   0   1   1   1   1   9   0   ..  2729   5   3   4   1   5   1   0   0   9   1   ..  1625 rows × 22 columns Out[516 ... In [518 ... Out[518 ... In [520 ... In [522 ... In [524 ... Out[524 ... In [526 ... Out[526 ... In [528 ... In [530 ... Out[530 ...  ▾   GaussianNB  GaussianNB()  ▾   GaussianNB  GaussianNB()

# %% [markdown]
# --- End of Page 15 ---

# %% [markdown]
# model . score ( x_test , y_test )    0.9224615384615384  from   sklearn.metrics   import   accuracy_score    GaussiNB_accu = accuracy_score ( y_test , y_pred )    GaussiNB_accu    0.9224615384615384  Error_rate = 1 - accuracy_score ( y_test , y_pred )    Error_rate    0.07753846153846156  from   sklearn.metrics   import   classification_report    print ( classification_report ( y_test , y_pred ))                  precision    recall  f1-score   support                0       0.93      0.93      0.93       861              1       0.92      0.92      0.92       764         accuracy                           0.92      1625      macro avg       0.92      0.92      0.92      1625   weighted avg       0.92      0.92      0.92      1625      from   sklearn.metrics   import   confusion_matrix    CM = confusion_matrix ( y_test , y_pred )    CM    array([[797,  64],          [ 62, 702]])  sns . heatmap ( cm , annot = True , fmt = 'g' )    <Axes: > In [532 ... Out[532 ... In [534 ... In [536 ... In [538 ... Out[538 ... In [540 ... In [542 ... Out[542 ... In [544 ... In [546 ... In [548 ... In [550 ... In [552 ... Out[552 ... In [554 ... Out[554 ...

# %% [markdown]
# --- End of Page 16 ---

# %% [markdown]
# from   sklearn.naive_bayes   import   MultinomialNB    model = MultinomialNB ()    model    model . fit ( x_train , y_train )    y_pred = model . predict ( x_test )    y_pred    array([0, 0, 0, ..., 1, 0, 0])  model . score ( x_test , y_test )    0.7895384615384615  from   sklearn.metrics   import   accuracy_score    MultinomialNB_accu = accuracy_score ( y_test , y_pred )    MultinomialNB_accu    0.7895384615384615  Error_rate = 1 - accuracy_score ( y_test , y_pred )   In [556 ... In [558 ... In [560 ... Out[560 ... In [562 ... Out[562 ... In [564 ... In [566 ... Out[566 ... In [568 ... Out[568 ... In [570 ... In [572 ... In [574 ... Out[574 ... In [576 ...  ▾   MultinomialNB  MultinomialNB()  ▾   MultinomialNB  MultinomialNB()

# %% [markdown]
# --- End of Page 17 ---

# %% [markdown]
# Error_rate    0.21046153846153848  from   sklearn.metrics   import   confusion_matrix    CM = confusion_matrix ( y_test , y_pred )   CM    array([[809,  52],          [290, 474]])  sns . heatmap ( cm , annot = True , fmt = 'g' )    <Axes: >  from   sklearn.metrics   import   classification_report    print ( classification_report ( y_test , y_pred ))                  precision    recall  f1-score   support                0       0.74      0.94      0.83       861              1       0.90      0.62      0.73       764         accuracy                           0.79      1625      macro avg       0.82      0.78      0.78      1625   weighted avg       0.81      0.79      0.78      1625      from   sklearn.naive_bayes   import   BernoulliNB    model = BernoulliNB ()    model   In [578 ... Out[578 ... In [580 ... In [582 ... Out[582 ... In [584 ... Out[584 ... In [586 ... In [588 ... In [590 ... In [592 ... In [594 ... Out[594 ...  ▾   BernoulliNB  BernoulliNB()

# %% [markdown]
# --- End of Page 18 ---

# %% [markdown]
# model . fit ( x_train , y_train )    y_pred = model . predict ( x_test )    y_pred    array([0, 1, 0, ..., 0, 0, 0])  model . score ( x_test , y_test )    0.8295384615384616  from   sklearn.metrics   import   accuracy_score    BernoulliNB_accu = accuracy_score ( y_test , y_pred )    BernoulliNB_accu    0.8295384615384616  Error_rate = 1 - accuracy_score ( y_test , y_pred )    Error_rate    0.17046153846153844  from   sklearn.metrics   import   confusion_matrix    CM = confusion_matrix ( y_test , y_pred )   CM    array([[796,  65],          [212, 552]])  sns . heatmap ( cm , annot = True , fmt = 'g' )    <Axes: > In [596 ... Out[596 ... In [598 ... In [600 ... Out[600 ... In [602 ... Out[602 ... In [604 ... In [606 ... In [608 ... Out[608 ... In [610 ... In [612 ... Out[612 ... In [614 ... In [616 ... Out[616 ... In [618 ... Out[618 ...  ▾   BernoulliNB  BernoulliNB()

# %% [markdown]
# --- End of Page 19 ---

# %% [markdown]
# from   sklearn.metrics   import   classification_report    print ( classification_report ( y_test , y_pred ))                  precision    recall  f1-score   support                0       0.79      0.92      0.85       861              1       0.89      0.72      0.80       764         accuracy                           0.83      1625      macro avg       0.84      0.82      0.83      1625   weighted avg       0.84      0.83      0.83      1625      Random forest  from   sklearn.ensemble   import   RandomForestClassifier    rf_model1 = RandomForestClassifier ( random_state = 42 )    rf_model1 . fit ( x_train , y_train )    forest_pred = rf_model1 . predict ( x_test )    forest_pred    array([0, 1, 0, ..., 1, 1, 0])  rf_model1 . score ( x_test , y_pred )    0.8295384615384616 In [620 ... In [622 ... In [639 ... In [640 ... In [641 ... Out[641 ... In [642 ... In [643 ... Out[643 ... In [644 ... Out[644 ...  ▾   RandomForestClassifier  RandomForestClassifier(random_state=42)

# %% [markdown]
# --- End of Page 20 ---

# %% [markdown]
# rf_accuracy = accuracy_score ( y_test , forest_pred )    rf_accuracy    1.0  forest_report = classification_report ( y_test , forest_pred )    print ( forest_report )                  precision    recall  f1-score   support                0       1.00      1.00      1.00       861              1       1.00      1.00      1.00       764         accuracy                           1.00      1625      macro avg       1.00      1.00      1.00      1625   weighted avg       1.00      1.00      1.00      1625      forestcm = confusion_matrix ( y_test , forest_pred )    forestcm    array([[861,   0],          [  0, 764]])  sns . heatmap ( forestcm , annot = True , fmt = 'g' )    <Axes: >  decision Tree  from   sklearn.tree   import   DecisionTreeClassifier    tree = DecisionTreeClassifier ()    tree . fit ( x_train , y_train )   In [645 ... In [646 ... Out[646 ... In [647 ... In [648 ... In [649 ... In [650 ... Out[650 ... In [651 ... Out[651 ... In [653 ... In [654 ... In [655 ...

# %% [markdown]
# --- End of Page 21 ---

# %% [markdown]
# tree_pred = tree . predict ( x_test )    tree_pred    array([0, 1, 0, ..., 1, 1, 0])  tree . score ( x_test , y_test )    1.0  Decision_accuracy = accuracy_score ( y_test , tree_pred )    Decision_accuracy    1.0  report_tree = classification_report ( y_test , tree_pred )   print ( report_tree )                  precision    recall  f1-score   support                0       1.00      1.00      1.00       861              1       1.00      1.00      1.00       764         accuracy                           1.00      1625      macro avg       1.00      1.00      1.00      1625   weighted avg       1.00      1.00      1.00      1625      decisioncm = confusion_matrix ( y_test , tree_pred )    decisioncm    array([[861,   0],          [  0, 764]])  sns . heatmap ( decisioncm , annot = True , fmt = 'g' )    <Axes: > Out[655 ... In [657 ... In [658 ... Out[658 ... In [659 ... Out[659 ... In [660 ... In [661 ... Out[661 ... In [662 ... In [663 ... In [664 ... Out[664 ... In [665 ... Out[665 ...  ▾   DecisionTreeClassifier  DecisionTreeClassifier()

# %% [markdown]
# --- End of Page 22 ---

# %% [markdown]
# models   =   [        'logistic' , 'GaussiNB' , 'MultinomialNB' , 'BernoulliNB' , 'rf_accuracy' , 'Decisiontree' ]  scores   =   [ logistic_accu , GaussiNB_accu   , MultinomialNB_accu , BernoulliNB_accu , rf_accurac  scores    [0.9526153846153846,    0.9224615384615384,    0.7895384615384615,    0.8295384615384616,    1.0,    1.0]  plt . figure ( figsize = ( 15 ,   10 )) sns . barplot ( x = models ,   y = scores ,   hue = models ,   palette = 'coolwarm' )   plt . title ( "Comparison of Model Performance" )   plt . xticks ( rotation = 30 )   plt . ylim ( 0 ,   1 )   plt . show ()   In [666 ... In [667 ... In [668 ... Out[668 ... In [669 ...

# %% [markdown]
# --- End of Page 23 ---

# %% [markdown]
# Data visualization  plt . figure ( figsize = ( 12 ,   6 ))   sns . boxplot ( data = df )   plt . xticks ( rotation = 90 )   plt . title ( "Outlier Detection" )   plt . show ()   In [704 ...

# %% [markdown]
# --- End of Page 24 ---

# %% [markdown]
# sns . histplot ( df [ "class" ])    <Axes: xlabel='class', ylabel='Count'>  sns . histplot ( df [ "cap-shape" ])    <Axes: xlabel='cap-shape', ylabel='Count'> In [706 ... Out[706 ... In [708 ... Out[708 ...

# %% [markdown]
# --- End of Page 25 ---

# %% [markdown]
# sns . histplot ( df [ "cap-color" ])    <Axes: xlabel='cap-color', ylabel='Count'>  sns . scatterplot ( df )   plt . figure ( figsize = ( 10 ,   6 ))    <Figure size 1000x600 with 0 Axes> In [710 ... Out[710 ... In [712 ... Out[712 ...

# %% [markdown]
# --- End of Page 26 ---

# %% [markdown]
# <Figure size 1000x600 with 0 Axes>  sns . scatterplot ( x )    <Axes: > In [713 ... Out[713 ...

# %% [markdown]
# --- End of Page 27 ---

# %% [markdown]
# sns . scatterplot ( y )    <Axes: ylabel='class'>  sns . pairplot ( df )    <seaborn.axisgrid.PairGrid at 0x7f5edc2eeb50> In [714 ... Out[714 ... In [715 ... Out[715 ...

# %% [markdown]
# --- End of Page 28 ---

# %% [markdown]
# data = df    for   feature   in   data :        plt . figure ( figsize = ( 3 , 2 ))        sns . boxplot ( y = df [ feature ])          plt . title ( f 'Boxplot of  { feature } ' )        plt . show ()   In [717 ...

# %% [markdown]
# --- End of Page 29 ---

# %% [markdown]
# --- End of Page 30 ---

# %% [markdown]
# --- End of Page 31 ---

# %% [markdown]
# --- End of Page 32 ---

# %% [markdown]
# --- End of Page 33 ---

# %% [markdown]
# In [ ]: In [ ]: In [ ]: In [ ]:
